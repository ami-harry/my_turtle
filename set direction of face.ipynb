# %%
import turtle as t

# %%
a=t.Turtle()

# %%
a.setheading(90) #default direction is right means (0) and it will set heading according to given paramater
# this is useful when we use to draw shapes

# %%
# c='red'
# a.screen.bgcolor(c)
