# %%
import numpy as np
import pandas as pd

# %%
arr=np.array([[1,2,3],[34,45,23]])

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [34, 45, 23]])

# %%
# df=pd.DataFrame(arr)

# %%
# df

# %%
# df.to_csv('hello.xlsx')

# %%
# reading the file
f=pd.read_csv('hii.xlsx')
print('file read sucessfully')
# Out:
# file read sucessfully

# %%
    f
# Out:
#    Unnamed: 0      0     1       2
# 0           0  hello  this      is
# 1           1  ronik  room  laptop

# %%
(f
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-d8711d29ed7d> in <module>
# ----> 1 f[0]
#
# ...
