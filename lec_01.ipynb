# %%
import turtle as t

# %%
tut_object=t.Turtle()

# %%
tut_object.color('red','yellow')

# %%
tut_object.pensize(10)
tut_object.forward(100)

# %%
# if we want to use RGB color code then firstly we have to use turtle.colormode(255) 
# then after we can give rgb values

# %%
t.colormode(255)

# %%
tut_object.color(154,55,214)

# %%
tut_object.pensize(20)
tut_object.forward(100)
