# %%
import turtle as t

# %%
a=t.Turtle()

# %%
# a.shape()

# %%
# a.shape('square')

# %%
# a.shapesize(10)

# %%
a.hideturtle()

# %%
# a.screen.bgcolor('red')

# %%
a.screen.bgpic("download.gif")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-9-5436b5afcfc8> in <module>
# ----> 1 a.screen.bgpic("download.gif")
#
# /usr/lib/python3.8/turtle.py in bgpic(self, picname)
#    1479             return self._bgpicname
#    1480         if picname not in self._bgpics:
# -> 1481             self._bgpics[picname] = self._image(picname)
#    1482         self._setbgpic(self._bgpic, self._bgpics[picname])
#    1483         self._bgpicname = picname
#
# /usr/lib/python3.8/turtle.py in _image(filename)
#     477         imagedata from a gif-file named filename.
#     478         """
# --> 479         return TK.PhotoImage(file=filename)
#     480
#     481     def __init__(self, cv):
#
# /usr/lib/python3.8/tkinter/__init__.py in __init__(self, name, cnf, master, **kw)
#    4059         Valid resource names: data, format, file, gamma, height, palette,
# ...
