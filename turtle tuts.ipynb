# %%
import turtle

# %%
a=turtle.Turtle() #creating the window

# %%
# a.shape()

# %%
# a.shape('square')

# %%
# a

# %%
# a.shapesize(10) #it will adjust the size of the turtle

# %%
# a.shape('circle') #to reshapre the turtle

# %%
# a.shape('turtle')

# %%
# changing the background color
# a.screen.bgcolor('red')
# a.color('white') #it will change the color of cursor

# %%
# we can set an image in the turtle background, it always be in .gif format and the picture will be in the same folder

# %%
a.hideturtle() #this will hide the turtle

# %%
a.screen.bgpic("a.gif") #this will set this pic
