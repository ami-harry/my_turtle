# %%
import turtle as t

# %%
s=t.Turtle()

# %%
s.screen.bgcolor('black')
s.color('white')

# %%
# s.forward(100) #this will move 100px in forward direction

# %%
s.hideturtle() #it will hide the turtle

# %%
# we can change the thickness of the turtle, means how much bole our line will be

# %%
s.pensize(10) #it will make line 10px bold

# %%
s.pencolor('green')

# %%
s.fd(200)
s.pencolor("pink")

# %%
# s.backward(200)

# %%
s.setheading(90)
s.fd(200)
s.pencolor("white")
s.setheading(180)
s.fd(200)
s.pencolor("yellow")
s.setheading(270)
s.fd(200)
