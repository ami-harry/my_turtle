# %%
import turtle as t

# %%
tut_obj=t.Turtle()

# %%
tut_obj.color('red','black')

# %%
tut_obj.shape('turtle')

# %%
#to set backgroung color we will use screen class , so we will make an instance/object of screen class then we will use their methdos

# %%
s=t.Screen()

# %%
s.bgcolor('yellow') # it will fill background color as yellow

# %%
# to use RGB we will use turtle.colormode(255)

# %%
t.colormode(255)

# %%
s.bgcolor(12,125,215)

# %%
# to set the title of the window then we will use screen_object.title('name')

# %%
s.title('harry')

# %%
# we can use bg pic also, the image file in .gif format and in the same folder

# %%
s.bgpic("myimage.gif")
